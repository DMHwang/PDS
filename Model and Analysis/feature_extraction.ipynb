# %%
__author__ = 'Stefano Mauceri'
__email__ = 'mauceri.stefano@gmail.com'


"""
In order to run the algorithm you need simply to:
    1)
    - Put your data in the "data" folder using the
    exact same format as the examples provided.
    - Please follow the same method to name
    files.
    - Data is organised as .npy files where we have:
    (n samples, time series length).
    - Data must contain at least two classes.

    2)
    - Go to the "MAIN" section below.
    - Put the name of your dataset in the dataset list.
    - Set the number of features to be extrated.
    - Finally, run the present script.

    3) Collect results in the "results" folder.


If you want to modify the algorithm it is a
completely different story.
Some changes may be easy, others may require
you to modify multiple files across the package.

I may be able to support you if you contact me via email.

For now, I can point you to some of the main files
you may want to work with:
- GRAMMAR: /grammars/tsc_grammar.bnf
- EVOLUTIONARY PARAMETERS: /parameters/tsc_parameters.txt
- FITNESS FUNCTION: /src/fitness/tsc_fitness.py
- FUNCTIONS USED IN THE GRAMMAR (PRIMITIVES): /src/fitness/math_functions.py

"""



# =============================================================================
# IMPORT
# =============================================================================



import os
import re
import subprocess
import numpy as np
import pandas as pd
from src.fitness.math_functions import *



# =============================================================================
# FUNCTIONS
# =============================================================================



def extract_features(X, phenotype):
    T = X
    return eval(phenotype)


def exists_or_create(path):
    if not os.path.exists(path):
        os.makedirs(path)


def customise_default_grammar(dataset, cwd):
    path_default = os.path.join(cwd, 'grammars', 'tsc_grammar.bnf')
    path_customised = os.path.join(cwd, 'grammars', f'tsc_grammar_{dataset}.bnf')

    grammar = open(path_default, 'r')
    new_grammar = open(path_customised, 'w')

    for line in grammar:
        if line.startswith('<lb>'):
            line = f'<lb> ::= GE_RANGE:{ts_length}\n'
        new_grammar.write(line)

    grammar.close()
    new_grammar.close()



def read_parameters(path):
    df = pd.read_csv(path, sep=':', names=['K', 'V'])
    K = [re.sub(r'\s+', '', i) for i in df.K.values]
    V = [re.sub(r'\s+', '', i) for i in df.V.values]
    return dict(zip(K, V))



def save_last_feature(parameters):

    run = parameters['RUN_NUMBER']
    generations = parameters['GENERATIONS']
    fts = parameters['FEATURE_NUMBER']
    class_ = parameters['CLASS']

    current_save_dir = os.path.abspath(os.path.join(os.getcwd(), 'results', parameters['EXPERIMENT_NAME']))
    current_save_dir = current_save_dir.split(os.path.sep)[:-2]
    current_save_dir = os.path.sep.join(current_save_dir)

    phen_path = os.path.join(current_save_dir,
                             f'F_{fts}',
                             f'CLASS={class_}_RUN={run}',
                             f'{generations}.txt')

    with open(phen_path, 'r') as phenotype_file:
        for line in phenotype_file:
            if line.startswith('Phenotype:'):
                phenotype = next(phenotype_file).strip()

    save_phen_folder = os.path.join(current_save_dir, 'PHENOTYPES')
    exists_or_create(save_phen_folder)
    save_phen_path = os.path.join(save_phen_folder, f'CLASS={class_}_RUN={run}.txt')
    save_phen_file = open(save_phen_path, 'a')
    save_phen_file.write(phenotype + '\n')
    save_phen_file.close()



def write_parameters(parameters, path):
    with open(path, 'w') as new_parameters:
        for k,v in parameters.items():
            new_parameters.write(f'{k}: {v}\n')
    new_parameters.close()



def wrapper(dataset, class_, feature_number, cwd, parameters_file='tsc_parameters.txt', save_last=False):

    path_to_ponyge = os.path.join(cwd, 'src', 'ponyge.py')

    path_default = os.path.join(cwd, 'parameters', f'{parameters_file}')
    parameters_default = read_parameters(path_default)

    parameters = {'CLASS':class_,
                  'FEATURE_NUMBER':feature_number,
                  'DATASET_NAME':dataset,
                  'GRAMMAR_FILE':f'tsc_grammar_{dataset}.bnf',
                  'MUTATE_DUPLICATES':True}

    RUNS = int(parameters_default['RUNS'])
    for run in range(1, RUNS+1):
        exp_name = os.path.sep.join([f'{dataset}_KNN', f'F_{feature_number}', f'CLASS={class_}_RUN={run}'])

        parameters['RUN_NUMBER'] = run
        parameters['EXPERIMENT_NAME'] = exp_name

        parameters_default.update(parameters)
        path_customised_parameters = os.path.join(cwd, 'parameters', f'tsc_parameters_{dataset}_{class_}_{feature_number}.txt')
        write_parameters(parameters_default, path_customised_parameters)

        ex = f'python {path_to_ponyge} --parameters tsc_parameters_{dataset}_{class_}_{feature_number}.txt'
        subprocess.run(ex, shell=True, cwd=os.path.join(cwd, 'src'))

        # os.remove(path_customised_parameters)

        if save_last:
            save_last_feature(parameters_default)


# =============================================================================
# MAIN
# =============================================================================


# Target data-sets.
# dataset_list = ['SyntheticControl', 'GunPoint']
dataset_list = ['MiniSolarFlares']

# Number of features to be extracted.
features = 1

classes = [2]


for dataset in dataset_list:


    cwd = os.getcwd()
    path_to_dataset = os.path.join(cwd, 'data', dataset, '')


    # We need to know the time series length.
    # I read this argument from data.
    X = np.load(path_to_dataset + f'{dataset}_X_TRAIN.npy')
    ts_length = X.shape[1]


    # We need to know the positive class label.
    # In this example I run through all
    # the available class labels.
    # I read this argument from data.
    Y = np.load(path_to_dataset + f'{dataset}_Y_TRAIN.npy')

    if classes is None:
        classes, counts = np.unique(Y, return_counts=True)
        cls_counts = {i:j for i, j, in zip(classes, counts)}
    else:
        _classes, counts = np.unique(Y, return_counts=True)
        cls_counts = {i:j for i, j, in zip(_classes, counts) if i in classes}
    print(f'Dataset name: {dataset}')
    print(f'Classes: {cls_counts}')

    # We need to modify the default grammar
    # to account for the current time series length.
    customise_default_grammar(dataset, cwd)


    # Now for each feature and
    # for each class
    # we call the algorithm.
    for f in range(1, features+1):
        for c in classes:
            print(f'Generating feature {f} for class {c}.')
            if f == features:
                save_last = True
            else:
                save_last = False
            wrapper(dataset, c, f, cwd,
                    parameters_file='tsc_parameters.txt',
                    save_last=save_last)


# =============================================================================
# END
# =============================================================================
# Out:
# Dataset name: MiniSolarFlares
# Classes: {2: 18}
# Generating feature 1 for class 2.
#
# Start:	 2023-11-29 16:21:02.634560
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.006775067750677599
#   Phenotype: extract(T, 24, 43, False, function = lambda T:((Min(T)*AbsSum(T))*(Mean(T)-(Min(T)*Mean(T)))))
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.0
#   gen : 	 40
#   invalids : 	 107
#   max_genome_length : 	 319
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 90.0
#   max_used_codons : 	 70.0
#   min_genome_length : 	 187
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 281756
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 4.195879936218262
#   total_inds : 	 20500
#   total_time : 	 199.49713397026062
#   unique_inds : 	 16842
#   unused_search : 	 17.84390243902439
#
#
#
# Start:	 2023-11-29 16:28:16.217009
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.01693766937669372
#   Phenotype: extract(T, 54, 17, True, function = lambda T:Autocorrelation(T))
#   Genome: [34, 474, 142, 497, 200, 519, 190, 168, 726, 720, 469, 192, 210, 758, 674, 925, 94, 937, 212, 977, 595, 993, 555, 152, 468, 704, 440, 703, 786, 284, 362, 123, 549, 977, 972, 876, 988, 21, 964, 490, 828, 509, 724, 617, 109, 645, 736, 4, 210, 885, 291, 611, 102, 445, 13, 377, 275, 520, 397, 197, 869, 197, 382, 556, 798, 20, 766, 744, 421, 480, 39, 424, 544, 541, 898, 783, 267, 197, 497, 997, 130, 346, 176, 559, 840, 340, 517, 33, 228, 568, 302, 412, 916, 75, 269, 391, 482, 478, 716, 86, 114, 300, 608, 7, 787, 328, 146, 629, 820, 954, 673, 266, 357, 633, 527, 211, 454, 195, 100, 363, 291, 978, 863, 277, 51, 105, 4, 322, 652, 747, 455, 489, 298, 923, 172, 417, 561, 366, 875, 673, 71, 513, 320, 237, 606, 955, 480, 184, 689, 139, 79, 647, 332, 691, 103, 142, 856, 142, 883, 965, 678, 267, 582, 599, 337, 953, 639, 880, 996, 717, 157, 119, 481, 15, 211, 119, 613, 713, 910, 384, 625, 353, 364, 642, 839, 7, 391, 602, 456, 840, 835, 86, 237, 501, 189, 488, 164, 775, 751, 354, 33, 411]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.3075986895639191
#   ave_genome_length : 	 230.046
#   ave_tree_depth : 	 8.714876033057852
#   ave_tree_nodes : 	 24.206611570247933
#   ave_used_codons : 	 17.46694214876033
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.01693766937669372
#   gen : 	 40
#   invalids : 	 262
#   max_genome_length : 	 311
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 91.0
#   max_used_codons : 	 71.0
#   min_genome_length : 	 157
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 240405
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 7.4462621212005615
#   total_inds : 	 20500
#   total_time : 	 237.9566879272461
#   unique_inds : 	 16309
#   unused_search : 	 20.443902439024384
#
#
#
# Start:	 2023-11-29 16:32:15.329664
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.009485094850948506
#   Phenotype: extract(T, 34, None, False, function = lambda T:((Median(T)*(LinearTrend(T)+(Min(T)-LinearTrend(T))))*(Max(T)*AbsSum(T))))
#   Genome: [542, 214, 729, 715, 530, 854, 836, 706, 115, 862, 557, 836, 936, 637, 134, 481, 168, 727, 66, 892, 941, 106, 12, 638, 280, 715, 881, 615, 553, 171, 600, 499, 790, 730, 213, 676, 553, 370, 940, 891, 248, 69, 443, 649, 749, 313, 470, 878, 938, 726, 418, 965, 174, 807, 804, 158, 203, 639, 446, 165, 500, 28, 725, 908, 35, 693, 491, 327, 183, 818, 701, 552, 460, 290, 637, 134, 375, 894, 968, 959, 849, 469, 506, 588, 866, 535, 67, 112, 975, 302, 543, 455, 771, 64, 563, 323, 429, 541, 574, 873, 759, 238, 80, 875, 385, 473, 622, 334, 821, 428, 760, 378, 735, 857, 765
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 7.464498996734619
#   total_inds : 	 20500
#   total_time : 	 247.27049493789673
#   unique_inds : 	 16115
#   unused_search : 	 21.390243902439025
#
#
#
# Start:	 2023-11-29 16:39:50.871961
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.008130081300813052
#   Phenotype: extract(T, 28, 35, True, function = lambda T:((Max(T)*(Below0(T)*(Mean(T)*Max(T))))*Mean(T)))
#   Genome: [78, 328, 324, 575, 698, 32, 954, 335, 94, 469, 876, 350, 70, 469, 344, 488, 414, 367, 928, 523, 536, 571, 928, 26, 697, 667, 36, 15, 775, 421, 247, 450, 550, 893, 211, 921, 960, 812, 434, 711, 425, 648, 794, 366, 517, 650, 967, 964, 608, 73, 33, 611, 282, 890, 580, 332, 397, 108, 934, 328, 441, 282, 430, 252, 508, 712, 304, 69, 567, 961, 424, 369, 661, 411, 489, 165, 853, 302, 961, 186, 38, 970, 433, 163, 126, 527, 833, 30, 25, 771, 294, 403, 296, 296, 321, 752, 34, 116, 620, 887, 37, 857, 372, 97, 572, 832, 594, 662, 684, 966, 567, 504, 492, 73, 108, 466, 866, 302, 848, 129, 792, 542, 910, 129, 571, 716, 704, 417, 724, 943, 487, 950, 442, 696, 692, 338, 444, 704, 994, 887, 368, 731, 485, 122, 283, 286, 582, 206, 595, 400, 591, 593, 859, 130, 49, 383, 377, 132, 180, 388, 225, 776, 975, 413, 639, 709, 773, 402, 311, 831, 604, 833, 625, 635, 136, 709, 46, 67, 811, 261, 750, 494, 717, 142, 863, 319, 60, 572, 207, 617, 580, 855, 999, 99, 593, 705, 704, 578, 757, 23, 713, 145, 878, 360, 86, 931, 906, 252, 612, 848, 175, 485, 730, 131, 119]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.24107842381741354
#   ave_genome_length : 	 236.208
#   ave_tree_depth : 	 8.954732510288066
#   ave_tree_nodes : 	 26.199588477366255
#   ave_used_codons : 	 19.137860082304528
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.008130081300813052
#   gen : 	 40
#   invalids : 	 220
#   max_genome_length : 	 295
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 81.0
#   max_used_codons : 	 63.0
#   min_genome_length : 	 155
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 207530
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 5.004081964492798
#   total_inds : 	 20500
#   total_time : 	 190.81682300567627
#   unique_inds : 	 17264
#   unused_search : 	 15.785365853658533
#
#
#
# Start:	 2023-11-29 16:43:02.812114
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.012195121951219523
#   Phenotype: extract(T, 55, 20, False, function = lambda T:(AQ(Max(T),CID(T))*(Min(T)-(((Median(T)+(MeanAbsChanges(T)-LinearTrend(T)))-AQ(Max(T),STD(T)))+AQ((Below0(T)*Max(T)),STD(T))))))
#   Genome: [379, 775, 596, 80, 943, 689, 826, 836, 815, 469, 383, 268, 923, 815, 809, 297, 438, 239, 260, 836, 37, 128, 160, 336, 658, 128, 53, 511, 334, 469, 297, 35, 527, 825, 128, 264, 882, 854, 43, 863, 154, 825, 990, 829, 315, 826, 100, 941, 608, 350, 103, 928, 486, 84, 52, 384, 606, 589, 281, 251, 497, 298, 544, 487, 909, 173, 689, 60, 558, 435, 391, 633, 224, 205, 81, 569, 520, 40, 520, 306, 677, 108, 579, 192, 466, 843, 958, 106, 797, 466, 25, 520, 902, 850, 19, 670, 823, 825, 732, 477, 

# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.3268079175828979
#   ave_genome_length : 	 245.556
#   ave_tree_depth : 	 9.444915254237289
#   ave_tree_nodes : 	 28.091101694915253
#   ave_used_codons : 	 20.65042372881356
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.004742547425474197
#   gen : 	 40
#   invalids : 	 433
#   max_genome_length : 	 378
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 106.0
#   max_used_codons : 	 83.0
#   min_genome_length : 	 160
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 180798
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 5.208510875701904
#   total_inds : 	 20500
#   total_time : 	 212.38046789169312
#   unique_inds : 	 16309
#   unused_search : 	 20.443902439024384
#
#
#
# Start:	 2023-11-29 16:51:13.221375
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.0060975609756098725
#   Phenotype: extract(T, 51, 23, True, function = lambda T:(Below0(T)*(AQ(Max(T),Above0(T))*Max(T))))
#   Genome: [701, 651, 240, 203, 806, 158, 574, 696, 956, 878, 642, 521, 811, 400, 383, 808, 952, 913, 162, 485, 952, 723, 306, 278, 199, 203, 643, 449, 332, 974, 307, 574, 878, 810, 828, 723, 859, 395, 573, 973, 86, 913, 149, 435, 383, 293, 284, 214, 573, 973, 86, 643, 449, 332, 974, 607, 430, 460, 961, 727, 808, 149, 810, 521, 823, 135, 86, 643, 761, 284, 573, 973, 128, 315, 73, 326, 435, 679, 944, 497, 918, 317, 257, 790, 488, 86, 89, 593, 699, 55, 753, 882, 115, 678, 832, 970, 610, 774, 82, 952, 913, 162, 425, 430, 106, 111, 947, 854, 77, 593, 615, 839, 951, 556, 871, 936, 692, 124, 710, 679, 83, 338, 825, 446, 211, 623, 969, 602, 875, 15, 121, 106, 782, 296, 319, 977, 34, 222, 858, 62, 33, 178, 325, 240, 290, 934, 785, 317, 873, 518, 108, 970, 157, 638, 857, 486, 383, 90, 995, 514, 158, 631, 559, 901, 854, 234, 122, 493, 959, 821, 771, 48, 127, 105, 306, 770, 499, 86, 741, 729, 504, 290, 590, 58, 624, 319, 333, 898, 780, 754, 53, 26, 657, 360, 830, 637, 236, 495, 600, 547, 270, 944, 972, 811, 563, 353, 789, 842, 59, 319, 497, 410, 887, 547, 985, 926, 416, 734, 912, 437, 810, 743, 616, 882, 335, 563, 396, 464, 618, 393, 95, 343, 327, 124, 97, 492, 674, 583, 825, 104, 659, 295, 246, 411, 613, 796, 812, 188, 537, 339, 122, 818, 629, 792, 751, 316, 913, 398, 574, 533, 786, 847, 258, 746, 962, 524, 686, 486, 90, 287, 136, 765, 806, 700, 606, 70, 580, 986, 205, 218, 54, 909, 9, 543, 479, 50]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.3074077323507048
#   ave_genome_length : 	 275.402
#   ave_tree_depth : 	 8.23360655737705
#   ave_tree_nodes : 	 23.653688524590162
#   ave_used_codons : 	 17.081967213114755
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.0060975609756098725
#   gen : 	 40
#   invalids : 	 361
#   max_genome_length : 	 430
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 106.0
#   max_used_codons : 	 83.0
#   min_genome_length : 	 116
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 204992
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 3.100890874862671
#   total_inds : 	 20500
#   total_time : 	 177.05023789405823
#   unique_inds : 	 16489
#   unused_search : 	 19.565853658536582
#
#
#
# Start:	 2023-11-29 16:54:11.465984
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0
 42, 106, 907, 62, 679, 45, 281, 213, 282, 381, 455, 237, 473, 703, 125, 499, 338, 946, 92, 693, 334, 71, 197, 10, 390, 660, 203, 873, 485, 881, 224, 136, 602, 246, 81, 748, 514, 30, 186, 100, 396, 963, 594, 334, 883, 727, 946, 203, 724, 307, 204, 197, 393, 327, 342, 613, 941, 204, 559, 25, 486, 721, 89, 17, 917, 459, 889, 540, 117, 497, 36, 36, 616, 267, 34, 293, 739, 765, 585, 954, 68, 836, 979, 301, 67, 898, 374, 341, 224]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.40583685187680607
#   ave_genome_length : 	 252.742
#   ave_tree_depth : 	 8.542857142857143
#   ave_tree_nodes : 	 24.022448979591836
#   ave_used_codons : 	 17.34081632653061
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.008130081300813052
#   gen : 	 40
#   invalids : 	 152
#   max_genome_length : 	 328
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 90.0
#   max_used_codons : 	 70.0
#   min_genome_length : 	 182
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 260804
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 8.476632118225098
#   total_inds : 	 20500
#   total_time : 	 3435.2936470508575
#   unique_inds : 	 15539
#   unused_search : 	 24.200000000000003
#
#
#
# Start:	 2023-11-29 17:55:17.766282
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.009485094850948506
#   Phenotype: extract(T, 31, 27, False, function = lambda T:(Mean(T)*(Below0(T)*Max(T))))
#   Genome: [416, 31, 276, 387, 81, 2, 850, 37, 44, 197, 222, 123, 242, 381, 723, 219, 731, 84, 397, 730, 411, 40, 477, 68, 962, 153, 881, 516, 436, 78, 731, 558, 883, 762, 879, 727, 243, 740, 95, 600, 869, 858, 351, 493, 882, 461, 756, 871, 840, 25, 845, 691, 644, 580, 996, 475, 778, 107, 313, 76, 67, 416, 558, 131, 631, 102, 505, 39, 980, 943, 919, 1000, 141, 243, 308, 539, 148, 917, 256, 533, 913, 225, 236, 226, 127, 563, 546, 317, 181, 352, 125, 753, 666, 935, 547, 334, 99, 994, 613, 727, 834, 858, 813, 170, 906, 81, 591, 43, 856, 772, 706, 155, 101, 10, 735, 21, 975, 248, 479, 21, 60, 976, 368, 534, 648, 313, 77, 40, 206, 664, 408, 328, 167, 760, 203, 468, 655, 0, 433, 346, 801, 919, 201, 423, 772, 417, 329, 210, 135, 43, 690, 805, 989, 31, 469, 260, 854, 93, 957, 334, 308, 481, 343, 213, 869, 578, 878, 698, 457, 935, 712, 395, 541, 312, 335, 352, 355, 626, 550, 840, 256, 486, 645, 697, 18, 477, 702, 916, 126, 180, 467, 86, 584, 598, 753, 725, 613, 112, 56, 164, 809, 664, 356, 28, 172, 723, 597, 796]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.33613824467483
#   ave_genome_length : 	 259.91
#   ave_tree_depth : 	 8.75206611570248
#   ave_tree_nodes : 	 25.66115702479339
#   ave_used_codons : 	 18.69214876033058
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.009485094850948506
#   gen : 	 40
#   invalids : 	 258
#   max_genome_length : 	 347
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 86.0
#   max_used_codons : 	 67.0
#   min_genome_length : 	 176
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 193046
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 2.9252049922943115
#   total_inds : 	 20500
#   total_time : 	 172.42554998397827
#   unique_inds : 	 16992
#   unused_search : 	 17.112195121951217
#
#
#
# Start:	 2023-11-29 17:58:11.386291
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0

# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.278881123127269
#   ave_genome_length : 	 240.654
#   ave_tree_depth : 	 9.05521472392638
#   ave_tree_nodes : 	 25.607361963190183
#   ave_used_codons : 	 18.63803680981595
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.008130081300813052
#   gen : 	 40
#   invalids : 	 297
#   max_genome_length : 	 322
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 85.0
#   max_used_codons : 	 66.0
#   min_genome_length : 	 146
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 262923
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 6.685024976730347
#   total_inds : 	 20500
#   total_time : 	 256.44173407554626
#   unique_inds : 	 16717
#   unused_search : 	 18.453658536585365
#
#
#
# Start:	 2023-11-29 18:06:02.903119
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.004742547425474197
#   Phenotype: extract(T, 25, 38, False, function = lambda T:(((Max(T)*(Max(T)+AbsSum(T)))*(Max(T)*(Below0(T)*AbsSum(T))))*Max(T)))
#   Genome: [116, 265, 234, 398, 965, 170, 250, 977, 554, 281, 350, 106, 26, 494, 444, 444, 808, 808, 902, 281, 710, 913, 808, 14, 34, 661, 752, 750, 902, 795, 485, 309, 503, 148, 69, 624, 579, 673, 750, 409, 292, 373, 241, 562, 715, 238, 63, 847, 857, 45, 73, 828, 842, 258, 985, 537, 408, 635, 428, 26, 284, 446, 893, 208, 22, 43, 85, 748, 839, 809, 769, 826, 986, 419, 353, 419, 353, 591, 850, 232, 70, 393, 875, 654, 89, 940, 454, 882, 1, 132, 286, 141, 437, 619, 471, 689, 745, 144, 997, 902, 54, 403, 354, 530, 251, 216, 468, 229, 347, 943, 577, 450, 927, 414, 375, 448, 188, 793, 772, 356, 248, 591, 881, 714, 800, 853, 201, 225, 322, 325, 97, 273, 261, 806, 158, 619, 637, 749, 415, 944, 632, 50, 416, 694, 503, 960, 498, 989, 29, 915, 259, 416, 916, 443, 297, 845, 158, 267, 648, 421, 240, 19, 957, 115, 876, 67, 329, 281, 904, 177, 117, 475, 26, 608, 623, 923, 291, 905, 472, 598, 350, 838, 413, 92, 664, 668, 52, 881, 716, 242, 18, 215, 360, 268, 892, 207, 985, 183, 121, 448, 36, 883, 606, 311, 435, 188, 497, 194, 206, 963, 88, 865, 7, 650, 758, 521, 58, 527, 87, 636, 880, 967, 757, 858, 650, 650, 92, 422, 198, 256, 784, 833, 113, 953, 358, 129, 457, 876, 346, 560, 651, 434, 200, 569, 294, 445, 29, 442, 149, 264, 398, 612, 56]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.3623421904950757
#   ave_genome_length : 	 264.22
#   ave_tree_depth : 	 8.735112936344969
#   ave_tree_nodes : 	 24.942505133470227
#   ave_used_codons : 	 18.125256673511295
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.004742547425474197
#   gen : 	 40
#   invalids : 	 216
#   max_genome_length : 	 352
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 106.0
#   max_used_codons : 	 83.0
#   min_genome_length : 	 191
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 234933
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 3.327741861343384
#   total_inds : 	 20500
#   total_time : 	 174.61791706085205
#   unique_inds : 	 16235
#   unused_search : 	 20.80487804878048
#
#
#
# Start:	 2023-11-29 18:08:58.895354
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.
126, 429, 20, 809, 669, 52, 836, 320, 133, 521, 542, 965, 58, 839, 809, 459, 138, 581, 403, 792, 51, 901, 47, 891, 17, 279, 211, 915, 315, 7, 840, 491, 402, 666, 914, 982, 68, 780, 742, 681, 134, 10, 221, 853, 48, 330, 380, 789, 193, 907, 356, 985, 309, 224, 221, 396, 766, 936, 145, 388, 914, 763, 256, 359, 408, 939, 755, 197, 683]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.3055636211124016
#   ave_genome_length : 	 247.406
#   ave_tree_depth : 	 10.029473684210526
#   ave_tree_nodes : 	 30.233684210526317
#   ave_used_codons : 	 22.33684210526316
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.01084010840108407
#   gen : 	 40
#   invalids : 	 202
#   max_genome_length : 	 329
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 91.0
#   max_used_codons : 	 71.0
#   min_genome_length : 	 161
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 217817
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 10.173265933990479
#   total_inds : 	 20500
#   total_time : 	 272.1504867076874
#   unique_inds : 	 16716
#   unused_search : 	 18.458536585365863
#
#
#
# Start:	 2023-11-29 18:17:03.332843
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.004742547425474197
#   Phenotype: extract(T, 33, 24, False, function = lambda T:(Below0(T)*((Max(T)+LinearTrend(T))*Median(T))))
#   Genome: [909, 33, 486, 324, 727, 353, 622, 417, 106, 164, 142, 800, 260, 286, 179, 216, 654, 516, 165, 946, 855, 213, 974, 726, 724, 841, 220, 884, 67, 656, 901, 890, 992, 271, 89, 264, 99, 646, 399, 162, 133, 152, 235, 97, 176, 98, 387, 336, 586, 666, 513, 884, 465, 142, 377, 415, 350, 228, 299, 190, 38, 460, 167, 168, 947, 969, 701, 744, 913, 280, 784, 485, 29, 735, 897, 413, 985, 794, 513, 852, 725, 675, 149, 194, 580, 365, 347, 56, 561, 682, 88, 553, 323, 536, 351, 854, 15, 869, 0, 596, 434, 278, 218, 73, 811, 554, 467, 653, 885, 742, 937, 352, 11, 13, 974, 635, 956, 143, 714, 474, 945, 0, 915, 342, 92, 600, 392, 101, 41, 255, 394, 396, 412, 896, 574, 572, 723, 651, 629, 236, 898, 292, 648, 51, 658, 677, 398, 130, 49, 148, 30, 426, 820, 376, 469, 525, 209, 314, 580, 990, 451, 884, 775, 472, 185, 635, 494, 104, 117, 373, 374, 213, 124, 617, 555, 211, 809, 934, 95, 140, 839, 882, 839, 162, 342, 74, 187, 257, 108, 970, 322, 419, 617, 573, 388, 801, 915, 927, 461, 64, 574, 861, 472]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.25115365664146155
#   ave_genome_length : 	 236.598
#   ave_tree_depth : 	 8.15071283095723
#   ave_tree_nodes : 	 23.114052953156822
#   ave_used_codons : 	 16.665987780040734
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.004742547425474197
#   gen : 	 40
#   invalids : 	 173
#   max_genome_length : 	 319
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 76.0
#   max_used_codons : 	 59.0
#   min_genome_length : 	 151
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 205828
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 3.441265821456909
#   total_inds : 	 20500
#   total_time : 	 170.0403687953949
#   unique_inds : 	 16817
#   unused_search : 	 17.965853658536588
#
#
#
# Start:	 2023-11-29 18:19:54.523258
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0
 414, 599, 188, 12, 150, 154, 41, 470, 929, 186, 508, 867, 152, 602, 61, 707, 677, 369, 735, 206, 507, 2, 857, 821, 719, 7, 117, 164, 871, 843, 160, 531, 660, 528, 434, 11, 169, 104, 924, 82, 921, 868, 616, 118, 616, 895, 869, 410, 229, 178, 214, 243, 2, 220, 404, 54, 511, 338, 588, 595, 108, 407, 904, 580, 79, 451, 365, 44, 267, 113, 663, 147, 609, 555, 452]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.30619478971232017
#   ave_genome_length : 	 232.222
#   ave_tree_depth : 	 9.038854805725972
#   ave_tree_nodes : 	 25.811860940695297
#   ave_used_codons : 	 18.803680981595093
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.016260162601625994
#   gen : 	 40
#   invalids : 	 215
#   max_genome_length : 	 314
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 95.0
#   max_used_codons : 	 74.0
#   min_genome_length : 	 161
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 236683
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 5.374843120574951
#   total_inds : 	 20500
#   total_time : 	 209.9652750492096
#   unique_inds : 	 16783
#   unused_search : 	 18.13170731707318
#
#
#
# Start:	 2023-11-29 18:26:24.293370
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.004065040650406471
#   Phenotype: extract(T, 47, None, True, function = lambda T:AQ(((Max(T)*Below0(T))*Max(T)),Below0(T)))
#   Genome: [281, 707, 633, 680, 959, 899, 815, 306, 410, 882, 502, 247, 787, 276, 396, 451, 562, 633, 586, 461, 727, 370, 465, 478, 982, 125, 607, 973, 63, 923, 966, 795, 987, 194, 318, 712, 370, 673, 446, 253, 338, 703, 734, 125, 414, 658, 736, 447, 739, 847, 149, 727, 724, 552, 469, 960, 176, 193, 586, 265, 913, 172, 780, 189, 905, 39, 964, 414, 63, 392, 332, 617, 545, 63, 135, 5, 154, 914, 680, 618, 266, 30, 247, 703, 988, 266, 430, 783, 703, 336, 320, 808, 546, 157, 8, 890, 96, 285, 211, 169, 368, 965, 522, 723, 502, 532, 574, 843, 721, 973, 849, 518, 890, 186, 782, 148, 821, 673, 257, 328, 358, 303, 55, 283, 517, 47, 718, 79, 719, 192, 236, 321, 731, 650, 253, 253, 553, 378, 867, 234, 627, 937, 691, 923, 221, 349, 558, 605, 36, 683, 987, 936, 916, 665, 230, 878, 27, 324, 340, 652, 632, 894, 687, 252, 593, 199, 499, 290, 807, 783, 936, 515, 522, 198, 869, 763, 654, 990, 457, 342, 626, 767, 443, 630, 594, 190, 235, 100, 551, 871, 464, 880, 342, 193, 12, 313, 639, 785, 45, 82, 7, 255, 572, 233, 315, 515, 860, 675, 418, 901, 212, 137, 387, 858, 551, 6, 953, 101, 878, 851, 759, 840, 6, 64]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.31244868542079496
#   ave_genome_length : 	 228.208
#   ave_tree_depth : 	 8.218623481781377
#   ave_tree_nodes : 	 23.540485829959515
#   ave_used_codons : 	 17.002024291497975
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.004065040650406471
#   gen : 	 40
#   invalids : 	 130
#   max_genome_length : 	 329
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 75.0
#   max_used_codons : 	 58.0
#   min_genome_length : 	 167
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 212881
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 10.039551973342896
#   total_inds : 	 20500
#   total_time : 	 266.64313101768494
#   unique_inds : 	 17010
#   unused_search : 	 17.024390243902445
#
#
#
# Start:	 2023-11-29 18:30:52.512141
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.015582655826558267
#   Phenotype: extract(T, 35, 32, True, function = lambda T:AQ(Below0(T),(AbsSum(T)*(Median(T)+CID(T)))))
# ...
#   max_used_codons : 	 95.0
#   min_genome_length : 	 177
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 190916
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 4.36109733581543
#   total_inds : 	 20500
#   total_time : 	 184.62605619430542
#   unique_inds : 	 16351
#   unused_search : 	 20.239024390243898
#
#
#
# Start:	 2023-11-29 18:38:25.918140
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.0013550135501354532
#   Phenotype: extract(T, 38, 27, True, function = lambda T:(Below0(T)*(Max(T)*(((Max(T)*(Below0(T)*AbsSum(T)))*Below0(T))*Max(T)))))
#   Genome: [346, 758, 742, 867, 94, 146, 934, 52, 55, 11, 934, 118, 94, 809, 934, 944, 482, 512, 542, 222, 944, 695, 446, 483, 752, 823, 307, 934, 599, 645, 247, 144, 818, 776, 166, 822, 42, 845, 53, 158, 485, 790, 410, 280, 250, 959, 493, 927, 340, 231, 914, 558, 634, 156, 637, 738, 284, 732, 688, 878, 626, 424, 573, 549, 679, 620, 344, 526, 366, 825, 525, 614, 785, 708, 991, 44, 187, 972, 975, 37, 403, 649, 633, 7, 34, 772, 90, 380, 516, 71, 684, 959, 773, 987, 937, 764, 884, 881, 30, 613, 187, 986, 88, 593, 611, 175, 626, 836, 574, 309, 973, 245, 71, 596, 404, 50, 40, 978, 587, 912, 958, 738, 616, 964, 352, 447, 91, 108, 768, 959, 730, 337, 335, 17, 818, 338, 348, 297, 830, 590, 71, 866, 628, 588, 621, 575, 717, 608, 330, 818, 617, 813, 303, 276, 642, 211, 62, 242, 935, 388, 753, 515, 751, 616, 441, 612, 8, 313, 961, 191, 971, 902, 173, 173, 353, 995, 84, 713, 600, 444, 159, 153, 456, 80, 975, 444, 753, 453, 111, 299, 771, 556, 185, 515, 697, 887, 652, 622, 207, 966, 268, 356, 493, 470, 379, 926, 828, 649, 887, 60, 962]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.36109791292718124
#   ave_genome_length : 	 235.318
#   ave_tree_depth : 	 9.54070981210856
#   ave_tree_nodes : 	 27.471816283924845
#   ave_used_codons : 	 20.068893528183715
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.0013550135501354532
#   gen : 	 40
#   invalids : 	 405
#   max_genome_length : 	 312
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 111.0
#   max_used_codons : 	 87.0
#   min_genome_length : 	 174
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 226768
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 11.621327877044678
#   total_inds : 	 20500
#   total_time : 	 290.5420649051666
#   unique_inds : 	 16628
#   unused_search : 	 18.88780487804877
#
#
#
# Start:	 2023-11-29 18:43:18.041476
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.010162601626016343
#   Phenotype: extract(T, 56, 29, True, function = lambda T:(Below0(T)*AQ((Max(T)*Max(T)),((AQ(Max(T),Max(T))*(Max(T)*AQ(FFT(T),ARCoeff(T))))+(Median(T)-AbsSum(T))))))
#   Genome: [506, 716, 272, 329, 336, 866, 350, 231, 582, 593, 483, 605, 398, 250, 213, 115, 94, 842, 256, 92, 394, 350, 47, 640, 400, 400, 213, 752, 398, 250, 842, 932, 871, 862, 125, 3, 767, 245, 329, 483, 998, 25, 528, 961, 906, 213, 517, 214, 464, 9, 497, 852, 560, 407, 43, 961, 423, 630, 101, 543, 214, 417, 461, 561, 247, 953, 71, 940, 175, 536, 162
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.013550135501354976
#   gen : 	 40
#   invalids : 	 161
#   max_genome_length : 	 344
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 96.0
#   max_used_codons : 	 75.0
#   min_genome_length : 	 180
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 262199
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 5.889662027359009
#   total_inds : 	 20500
#   total_time : 	 210.1051139831543
#   unique_inds : 	 16561
#   unused_search : 	 19.214634146341453
#
#
#
# Start:	 2023-11-29 18:50:33.989729
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.004742547425474197
#   Phenotype: extract(T, 30, 35, True, function = lambda T:(AbsSum(T)*(Below0(T)*(AQ(((AbsSum(T)*Median(T))*Max(T)),Median(T))*(Max(T)*Median(T))))))
#   Genome: [148, 810, 486, 575, 596, 677, 538, 211, 596, 677, 538, 630, 956, 698, 686, 158, 863, 596, 90, 698, 686, 229, 86, 630, 726, 132, 264, 868, 726, 659, 486, 315, 264, 868, 726, 132, 885, 366, 9, 64, 93, 281, 418, 171, 86, 86, 79, 418, 766, 165, 961, 826, 647, 984, 791, 229, 86, 86, 278, 984, 868, 299, 144, 366, 196, 189, 290, 470, 859, 610, 868, 726, 132, 831, 833, 527, 205, 739, 140, 802, 309, 597, 106, 772, 438, 304, 801, 388, 500, 172, 778, 248, 645, 624, 944, 825, 411, 76, 479, 14, 791, 154, 560, 402, 427, 236, 281, 743, 419, 90, 412, 536, 874, 61, 76, 560, 33, 376, 64, 863, 723, 425, 987, 249, 808, 601, 470, 429, 980, 627, 456, 900, 889, 58, 362, 781, 357, 785, 803, 164, 708, 696, 767, 115, 138, 905, 339, 599, 689, 94, 122, 677, 540, 272, 234, 339, 123, 313, 752, 508, 885, 185, 702, 472, 165, 308, 75, 328, 897, 557, 247, 677, 182, 26, 596, 582, 12, 215, 13, 610, 115, 884, 408, 170, 589, 409, 457, 433, 574, 93, 79, 197, 902, 61, 778, 196, 296, 955, 850, 80, 16, 166, 724, 518, 962, 852, 75, 427, 806, 984, 220, 782, 369, 87, 262, 999, 345, 519, 827, 126, 454, 997, 539, 984, 592, 206, 301, 6, 915, 974, 791, 49, 1, 774, 716, 160, 353, 699, 611, 935, 161, 251, 639, 932, 814, 853, 807, 1000, 785, 914, 944, 533, 872, 859, 963, 765, 306, 828, 818, 509, 238, 719, 764, 642, 44]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.24957634812080134
#   ave_genome_length : 	 278.442
#   ave_tree_depth : 	 9.463002114164905
#   ave_tree_nodes : 	 27.207188160676534
#   ave_used_codons : 	 19.938689217758984
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.004742547425474197
#   gen : 	 40
#   invalids : 	 235
#   max_genome_length : 	 377
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 106.0
#   max_used_codons : 	 83.0
#   min_genome_length : 	 162
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 214892
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 5.8014280796051025
#   total_inds : 	 20500
#   total_time : 	 202.42843317985535
#   unique_inds : 	 16381
#   unused_search : 	 20.09268292682927
#
#
#
# Start:	 2023-11-29 18:53:57.846173
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.0027100271002710175
#   Phenotype: extract(T, 28, 32, False, function = lambda T:(((Min(T)*Max(T))*ARCoeff(T))*Below0(T)))
#   Genome: [612, 328, 870, 332, 435, 662, 110, 698, 178, 176, 10, 315, 642, 378, 298, 589, 937, 181, 157, 574, 111, 264, 27, 486, 742, 883, 103, 364, 274, 373, 441, 970, 919, 711, 257, 213, 151, 684, 112, 908, 730, 437, 922, 12, 451, 444, 520, 221, 515, 2, 223, 883, 330, 147, 85, 879, 110, 943, 336, 938, 839, 111, 673, 968, 280, 118, 437, 298, 36, 722, 509, 647, 908, 775, 923, 59, 759, 532, 67, 554, 465, 412, 449, 935, 553, 94, 878, 185, 62, 74, 206, 617, 4, 313, 569, 97, 89, 553, 626, 985, 294, 164, 408, 5, 557, 884, 399, 969, 387, 242, 19, 828, 133, 499, 844, 343, 508, 291, 898, 371, 272, 618, 705, 849, 121, 959, 991, 320, 615, 591, 450, 139, 670, 445, 971, 500, 277, 371, 905, 508, 44, 74, 921, 814, 797, 478, 518, 894, 814, 930, 549, 568, 181, 891, 860, 261, 289, 40, 1, 833, 615, 942, 510, 733, 591, 32, 558, 847, 36, 946, 641, 93, 820, 176, 91, 409, 673, 351, 557, 333, 389, 427, 710, 35, 124, 589, 397, 179, 602, 70, 108, 185, 961, 756, 227, 119, 659, 997, 448, 904, 476, 237, 966, 75, 684, 478, 141, 834]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.33839495907585343
#   ave_genome_length : 	 213.57
#   ave_tree_depth : 	 7.906313645621181
#   ave_tree_nodes : 	 22.370672097759673
#   ave_used_codons : 	 16.05091649694501
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.0027100271002710175
#   gen : 	 40
#   invalids : 	 113
#   max_genome_length : 	 275
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 86.0
#   max_used_codons : 	 67.0
#   min_genome_length : 	 152
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 247139
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 6.994007110595703
#   total_inds : 	 20500
#   total_time : 	 256.87778997421265
#   unique_inds : 	 16652
#   unused_search : 	 18.77073170731707
#
#
#
# Start:	 2023-11-29 18:58:15.891159
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.0060975609756098725
#   Phenotype: extract(T, 25, 32, True, function = lambda T:(((Below0(T)*(AQ(AbsSum(T),AbsSum(T))*(TRAS(T)+Max(T))))*Mean(T))*AbsSum(T)))
#   Genome: [928, 205, 576, 872, 810, 290, 810, 692, 350, 647, 878, 760, 701, 878, 338, 677, 991, 934, 698, 996, 409, 836, 724, 409, 84, 256, 927, 294, 367, 94, 936, 82, 648, 84, 9, 379, 672, 809, 737, 970, 125, 392, 316, 257, 709, 117, 691, 622, 149, 746, 968, 345, 957, 620, 721, 761, 145, 125, 382, 48, 372, 304, 357, 767, 109, 974, 653, 196, 848, 784, 673, 264, 929, 921, 358, 142, 133, 372, 645, 16, 807, 586, 910, 987, 78, 1000, 980, 873, 253, 600, 977, 649, 755, 802, 323, 226, 830, 305, 207, 203, 689, 587, 741, 808, 946, 712, 480, 790, 363, 430, 951, 243, 374, 281, 18, 238, 869, 199, 345, 283, 527, 838, 745, 892, 412, 808, 683, 844, 124, 800, 682, 715, 679, 639, 755, 720, 934, 457, 461, 467, 949, 725, 420, 929, 982, 127, 602, 177, 229, 830, 813, 556, 637, 451, 82, 533, 592, 307, 815, 234, 716, 718, 906, 211, 800, 211, 931, 698, 443, 538, 101, 913, 190, 189, 852, 14, 753, 177, 107, 894, 669, 686, 967, 190, 946, 497, 699, 372, 434, 23, 922, 180, 834, 780, 755, 698, 372, 671, 301, 419, 337, 971, 588, 380, 354, 198, 6, 484, 519, 665, 304, 310, 36, 84, 373, 223, 57, 786, 736, 705, 990, 620, 482, 900, 49, 414, 522, 985, 486, 477, 468, 239, 513, 799, 152, 690, 722]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.29378704125826305
#   ave_genome_length : 	 249.208
#   ave_tree_depth : 	 9.378151260504202
#   ave_tree_nodes : 	 26.92436974789916
#   ave_used_codons : 	 19.71638655462185
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.0060975609756098725
#   gen : 	 40
#   invalids : 	 190
#   max_genome_length : 	 309
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 86.0
#   max_used_codons : 	 67.0
#   min_genome_length : 	 176
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 221740
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 4.40416407585144
#   total_inds : 	 20500
#   total_time : 	 178.0078341960907
#   unique_inds : 	 16854
#   unused_search : 	 17.785365853658547
#
#
#
# Start:	 2023-11-29 19:01:15.064645
#
# Warning: Grammar contains unit production for production rule <F>
#          Unit productions consume GE codons.
# Evolution: 97% complete
#
# Best:
#   Fitness:	 0.01490514905149054
#   Phenotype: extract(T, 17, 54, True, function = lambda T:Autocorrelation(T))
#   Genome: [162, 77, 670, 594, 406, 409, 904, 827, 226, 605, 440, 942, 140, 311, 403, 298, 139, 880, 70, 977, 379, 40, 856, 995, 324, 507, 755, 454, 417, 680, 959, 475, 960, 932, 292, 306, 223, 690, 392, 711, 798, 345, 981, 784, 787, 266, 489, 932, 203, 145, 94, 135, 818, 822, 90, 196, 50, 44, 933, 77, 792, 465, 600, 435, 634, 192, 528, 834, 728, 299, 678, 828, 677, 271, 534, 760, 139, 374, 793, 210, 821, 294, 301, 116, 205, 101, 517, 911, 697, 446, 690, 118, 939, 298, 277, 927, 897, 380, 569, 891, 823, 943, 852, 76, 300, 33, 84, 188, 405, 978, 653, 304, 68, 577, 369, 354, 674, 349, 645, 828, 888, 822, 911, 895, 610, 732, 146, 657, 678, 456, 648, 691, 833, 978, 935, 933, 996, 776, 302, 315, 179, 267, 955, 789, 78, 937, 681, 385, 747, 427, 183, 476, 825, 425, 136, 508, 338, 0, 98, 198, 818, 121, 90, 764, 655, 358, 90, 122, 1, 195, 779, 533, 100, 996, 79, 375, 165, 456, 685, 134, 597, 662, 303, 502, 5, 770]
# ______
#
#   ave_Pearson_corr : 	 nan
#   ave_auroc : 	 nan
#   ave_fitness : 	 0.31447456384378164
#   ave_genome_length : 	 247.128
#   ave_tree_depth : 	 8.753623188405797
#   ave_tree_nodes : 	 25.00414078674948
#   ave_used_codons : 	 18.074534161490682
#   best_Pearson_corr : 	 nan
#   best_auroc : 	 nan
#   best_fitness : 	 0.01490514905149054
#   gen : 	 40
#   invalids : 	 324
#   max_genome_length : 	 349
#   max_tree_depth : 	 20.0
#   max_tree_nodes : 	 105.0
#   max_used_codons : 	 82.0
#   min_genome_length : 	 177
#   min_tree_depth : 	 4.0
#   min_tree_nodes : 	 10.0
#   min_used_codons : 	 6.0
#   regens : 	 281776
#   runtime_error : 	 0
#   time_adjust : 	 0
#   time_taken : 	 5.607589960098267
#   total_inds : 	 20500
#   total_time : 	 228.79518008232117
#   unique_inds : 	 16051
#   unused_search : 	 21.702439024390245
